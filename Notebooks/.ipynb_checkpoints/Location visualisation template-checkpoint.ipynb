# %% [markdown]
# ## Location visualisation template

# %%
# Import libraries
import pandas as pd
import json

#in order of complexity we import the different plotly libraries
import plotly.express as px
import plotly.graph_objects as go
import datashader as ds

import dask.dataframe as dd #alternative to pandas, is faster with large datasets

# %%
token = 'pk.eyJ1IjoibW9zaGEtbGFuZ2VyYWsiLCJhIjoiY2t3ZGoxMmtxMGt2ZzJudDN5NXA0YWQ4ciJ9.6QIBuYFeAajMhniiNVU-GA'

# %%
# Load some data with longitude and langitude
file_path = '/Users/MoshaLangerak_1/Documents/GitHub/visualisation_group_25/Data/df_2020.csv'
file_path_2 = '/Users/MoshaLangerak_1/Documents/GitHub/visualisation_group_25/Data/all_years_2000_2020.csv'
df_pd = pd.read_csv(file_path, low_memory=False)
df_pd_2 = pd.read_csv(file_path_2, low_memory=False)

# %%
# with plotly.express it is very easy to create a scatterplot with a map, here an example with data from the library
df_iso = px.data.gapminder().query("year == 2007")
fig = px.scatter_geo(df_iso, locations="iso_alpha", # in this case the locations are based on iso codes, e.g. the Netherlands is NLD
                     size="pop", # size of markers, "pop" is one of the columns of gapminder
                     )
fig.show()

# %%
# fig_map_box = px.scatter_mapbox(df_pd, #which data to use, just a pandas dataframe
#                         lat='latitude', #which column to use for latitude
#                         lon='longitude', #which column to use for longitude
#                         hover_data =['accident_index'], #what data to show when hovering over a data point
#                         color='accident_severity', # what colour to give the data, can work with both numerical and categorical variables
#                         size_max=100,
#                         mapbox_style='carto-darkmatter')

# fig_map_box.update_layout(margin={'r':0, 't':0, 'l':0, 'b':0},
#                           mapbox_zoom=4, # use this to zoom in on the map
#                           mapbox_center_lat = 54.5, # use this to align the map on latitude
#                           mapbox_center_lon = -2 # use this to align the map on longitude
#                          )
# fig_map_box.show()

# %%
df_pd
# Out:
#         Unnamed: 0 accident_index  accident_year accident_reference  \
# 0                0  2020010219808           2020           10219808
# 1                1  2020010220496           2020           10220496
# 2                2  2020010228005           2020           10228005
# 3                3  2020010228006           2020           10228006
# 4                4  2020010228011           2020           10228011
# ...            ...            ...            ...                ...
# 374614         456  2020622000914           2020                NaN
# 374615         457  2020622100016           2020                NaN
# 374616         458  2020990982390           2020                NaN
# 374617         459  2020990982411           2020                NaN
# 374618         460  2020991010048           2020                NaN
#
#         vehicle_reference  vehicle_type  towing_and_articulation  \
# 0                     1.0           9.0                      9.0
# 1                     1.0           9.0                      0.0
# 2                     1.0           9.0                      0.0
# 3                     1.0           8.0                      0.0
# 4                     1.0           9.0                      0.0
# ...                   ...           ...                      ...
# 374614                1.0          90.0                      NaN
# 374615                2.0          90.0                      NaN
# 374616                1.0          90.0                      NaN
# 374617                2.0          90.0                      NaN
# 374618                2.0          90.0                      NaN
#
#         vehicle_manoeuvre  vehicle_direction_from  vehicle_direction_to  ...  \
# 0                     5.0                     1.0                   5.0  ...
# 1                     4.0                     2.0                   6.0  ...
# 2                    18.0                    -1.0                  -1.0  ...
# 3                    18.0                     1.0                   5.0  ...
# 4                    18.0                     3.0                   7.0  ...
# ...                   ...                     ...                   ...  ...
# 374614                NaN                     NaN                   NaN  ...
# 374615                NaN                     NaN                   NaN  ...
# 374616                NaN                     NaN                   NaN  ...
# 374617                NaN                     NaN                   NaN  ...
# 374618                NaN                     NaN                   NaN  ...
#
#         pedestrian_location  pedestrian_movement  car_passenger  \
# 0                       NaN                  NaN            NaN
# 1                       NaN                  NaN            NaN
# 2                       NaN                  NaN            NaN
# 3                       NaN                  NaN            NaN
# 4                       NaN                  NaN            NaN
# ...                     ...                  ...            ...
# 374614                  NaN                  NaN            NaN
# 374615                  NaN                  NaN            NaN
# 374616                  NaN                  NaN            NaN
# 374617                  NaN                  NaN            NaN
# 374618                  NaN                  NaN            NaN
#
#         bus_or_coach_passenger  pedestrian_road_maintenance_worker  \
# 0                          NaN                                 NaN
# 1                          NaN                                 NaN
# 2                          NaN                                 NaN
# 3                          NaN                                 NaN
# 4                          NaN                                 NaN
# ...                        ...                                 ...
# 374614                     NaN                                 NaN
# 374615                     NaN                                 NaN
# 374616                     NaN                                 NaN
# 374617                     NaN                                 NaN
# 374618                     NaN                                 NaN
#
#         casualty_type  casualty_home_area_type  casualty_imd_decile  \
# 0                 NaN                      NaN                  NaN
# 1                 NaN                      NaN                  NaN
# 2                 NaN                      NaN                  NaN
# 3                 NaN                      NaN                  NaN
# 4                 NaN                      NaN                  NaN
# ...               ...                      ...                  ...
# 374614            NaN                      NaN                  NaN
# 374615            NaN                      NaN                  NaN
# 374616            NaN                      NaN                  NaN
# 374617            NaN                      NaN                  NaN
# 374618            NaN                      NaN                  NaN
#
#         accident_ref_no      vehicle_text
# 0                   NaN               NaN
# 1                   NaN               NaN
# 2                   NaN               NaN
# 3                   NaN               NaN
# 4                   NaN               NaN
# ...                 ...               ...
# 374614        622000914  electric scooter
# 374615        622100016  electric scooter
# 374616        990982390  electric scooter
# 374617        990982411  electric scooter
# 374618        991010048  electric scooter
#
# [374619 rows x 77 columns]

# %%
df_pd_2
# Out:
#          Unnamed: 0  Unnamed: 0.1 accident_index  vehicle_type  \
# 0                 0             0  2000010SU0982           109
# 1                 1             1  2000010SU0982           109
# 2                 2             2  2000010SU0982           109
# 3                 3             3  2000010SU0982           109
# 4                 4             4  2000010SU0982           109
# ...             ...           ...            ...           ...
# 8751022     3050050       3050050  2020990982348             9
# 8751023     3050051       3050051  2020990982348             9
# 8751024     3050052       3050052  2020990982348             9
# 8751025     3050053       3050053  2020990982350             9
# 8751026     3050054       3050054  2020990982350             9
#
#          towing_and_articulation  vehicle_manoeuvre  \
# 0                              0                  4
# 1                              0                  4
# 2                              0                  4
# 3                              0                  4
# 4                              0                  4
# ...                          ...                ...
# 8751022                        0                 18
# 8751023                        0                 10
# 8751024                        0                 10
# 8751025                        0                  5
# 8751026                        0                  5
#
#          vehicle_location_restricted_lane  junction_location  \
# 0                                       0                 -1
# 1                                       0                 -1
# 2                                       0                 -1
# 3                                       0                 -1
# 4                                       0                 -1
# ...                                   ...                ...
# 8751022                                 0                  1
# 8751023                                 0                  1
# 8751024                                 0                  1
# 8751025                                 0                  1
# 8751026                                 0                  1
#
#          skidding_and_overturning  hit_object_in_carriageway  ...  \
# 0                               1                          0  ...
# 1                               1                          0  ...
# 2                               1                          0  ...
# 3                               0                          0  ...
# 4                               0                          0  ...
# ...                           ...                        ...  ...
# 8751022                         0                          0  ...
# 8751023                         0                          0  ...
# 8751024                         0                          0  ...
# 8751025                         0                          4  ...
# 8751026                         0                          0  ...
#
#          age_band_of_casualty  casualty_severity  pedestrian_location  \
# 0                           8                  3                    0
# 1                           4                  3                    0
# 2                           7                  3                    0
# 3                           8                  3                    0
# 4                           4                  3                    0
# ...                       ...                ...                  ...
# 8751022                    11                  3                    0
# 8751023                    11                  2                    0
# 8751024                    11                  3                    0
# 8751025                     8                  3                    0
# 8751026                     8                  3                    0
#
#          pedestrian_movement  car_passenger  bus_or_coach_passenger  \
# 0                          0              0                       0
# 1                          0              0                       0
# 2                          0              0                       0
# 3                          0              0                       0
# 4                          0              0                       0
# ...                      ...            ...                     ...
# 8751022                    0              0                       0
# 8751023                    0              1                       0
# 8751024                    0              0                       0
# 8751025                    0              0                       0
# 8751026                    0              0                       0
#
#          pedestrian_road_maintenance_worker  casualty_type  \
# 0                                        -1            109
# 1                                        -1            109
# 2                                        -1            109
# 3                                        -1            109
# 4                                        -1            109
# ...                                     ...            ...
# 8751022                                   0              9
# 8751023                                   0              9
# 8751024                                   0              9
# 8751025                                   0              9
# 8751026                                   0              9
#
#          casualty_home_area_type  casualty_imd_decile
# 0                             -1                   -1
# 1                             -1                   -1
# 2                             -1                   -1
# 3                             -1                   -1
# 4                             -1                   -1
# ...                          ...                  ...
# 8751022                        2                    2
# 8751023                        2                    2
# 8751024                        2                    2
# 8751025                        2                    5
# 8751026                        2                    5
#
# [8751027 rows x 66 columns]

# %%
fig_den_box = px.density_mapbox(df_pd_2, #which data to use, just a pandas dataframe
                        lat='latitude', #which column to use for latitude
                        lon='longitude', #which column to use for longitude
                        hover_data =['accident_index'], #what data to show when hovering over a data point
                        z='accident_severity', # what colour to give the data, can work with both numerical and categorical variables
                        mapbox_style='light',
                        opacity = 0.5, # change the opacity of the oclours on the map
                        range_color = [0, 10]
                        ) # change the range of the z metric's colour scale)

fig_den_box.update_layout(margin={'r':0, 't':0, 'l':0, 'b':0},
                        mapbox_zoom=4, # use this to zoom in on the map
                        mapbox_center_lat = 54.5, # use this to align the map on latitude
                        mapbox_center_lon = -2, # use this to align the map on longitude
                        mapbox_accesstoken=token
                         )
fig_den_box.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-5eb9b4e9d7e6> in <module>
#      15                         mapbox_accesstoken=token
#      16                          )
# ---> 17 fig_den_box.show()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py in show(self, *args, **kwargs)
#    3395         import plotly.io as pio
#    3396
# -> 3397         return pio.show(self, *args, **kwargs)
#    3398
#    3399     def to_json(self, *args, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/plotly/io/_renderers.py in show(fig, renderer, validate, **kwargs)
#     399             )
#     400
# --> 401         ipython_display.display(bundle, raw=True)
#     402
#     403     # external renderers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     309     for obj in objs:
#     310         if raw:
# --> 311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
#     313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in publish_display_data(data, metadata, source, transient, **kwargs)
#     117         kwargs['transient'] = transient
#     118
# --> 119     display_pub.publish(
#     120         data=data,
#     121         metadata=metadata,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py in publish(self, data, metadata, source, transient, update)
#     127         # hooks before potentially sending.
#     128         msg = self.session.msg(
# --> 129             msg_type, json_clean(content),
#     130             parent=self.parent_header
#     131         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     175
#     176     if isinstance(obj, list):
# --> 177         return [json_clean(x) for x in obj]
#     178
#     179     if isinstance(obj, dict):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in <listcomp>(.0)
#     175
#     176     if isinstance(obj, list):
# --> 177         return [json_clean(x) for x in obj]
#     178
#     179     if isinstance(obj, dict):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     189         out = {}
#     190         for k,v in iteritems(obj):
# --> 191             out[unicode_type(k)] = json_clean(v)
#     192         return out
#     193     if isinstance(obj, datetime):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     175
#     176     if isinstance(obj, list):
# --> 177         return [json_clean(x) for x in obj]
#     178
#     179     if isinstance(obj, dict):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in <listcomp>(.0)
#     175
#     176     if isinstance(obj, list):
# --> 177         return [json_clean(x) for x in obj]
#     178
#     179     if isinstance(obj, dict):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py in json_clean(obj)
#     142         return obj
#     143
# --> 144     if isinstance(obj, numbers.Integral):
#     145         # cast int to int, in case subclasses override __str__ (e.g. boost enum, #4598)
#     146         return int(obj)
#
# KeyboardInterrupt:

# %%
df_districts = df_pd.groupby('local_authority_ons_district').sum().reset_index()
df_districts.drop(df_districts.columns.difference(['local_authority_ons_district', 'accident_severity', 'number_of_vehicles',
       'number_of_casualties']), 1, inplace=True)
df_districts.rename(columns = {'accident_severity':'Accident Severity', 'number_of_vehicles':'Number of vehicles', 'number_of_casualties':'Number of casualties'}, inplace = True)

# %%
df_districts.head()

# %%
# getting the geojson data (boandary data) for the UK
with open('Data/uk_local_areas/uk_la.geojson') as f:
    geojson = json.load(f)

# %%
# plot a choropleth plot with the json data
fig = px.choropleth(df_districts, geojson=geojson, color="Number of casualties",
                    locations="local_authority_ons_district", featureidkey="properties.geo_code",
                    projection="mercator"
                   )

fig.update_geos(fitbounds="locations", visible=False)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

# %%
# plot a choropleth plot with the json data
fig = go.Figure()
trace = []

lst = ['Accident Severity', 'Number of vehicles', 'Number of casualties']

for i in range(0, len(lst)):
    trace.append(px.choropleth(
        df_districts, geojson=geojson, color=lst[i],
        locations="local_authority_ons_district", featureidkey="properties.geo_code",
        projection="mercator",
        basemap_visible=False,
        title='Map of {} in the UK'.format(lst[i]),
    ),
     
)
# fig.add_trace(trace)

for trace_fig in trace:
    fig.add_trace(trace_fig)
    
trace[1].update_geos(fitbounds="locations", visible=False)
trace[1].update_layout(margin={"r":0,"t":0,"l":0,"b":0})
trace[1].show()

# %%
fig.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=list([
            dict(
                label="Number of accidents",
                args=["number_of_casualties", "choropleth"],
                method="update"
            ),
            dict(
                label="Number of casualties",
                args=["number_of_casualties", "choropleth"],
                method="update"
            ),
            dict(
                label="Accident severity",
                args=["number_of_accidents", "choropleth"],
                method="update"
            ),
            dict(
                label="Number of accidents per capita",
                args=["number_of_casualties", "choropleth"],
                method="update"
            ),
            dict(
                label="Number of casualties per capita",
                args=["number_of_casualties", "choropleth"],
                method="update"
            )
        ]),
            direction="down",
        ),
    ]
)

# trace[0]['basemap_visible'] = True

# %%
# make a fig object with a plot attached with the pandas df (WARNING: very slow)
fig = go.Figure(data=go.Scattergeo(
        lon = df['longitude'],
        lat = df['latitude'],
        text = df['accident_index'],
        mode = 'markers',
        marker_color = df['accident_severity'],
        ))

fig.update_layout(
        title = 'Accidents<br>Great Britain 2020',
        geo_scope='europe',
    )

fig.show()

# %%
#creating a datashader canvas
cvs = ds.Canvas(plot_width=1000, plot_height=1000)
agg = cvs.points(df, x='longitude', y='latitude')
# agg is an xarray object, see http://xarray.pydata.org/en/stable/
coords_lat, coords_lon = agg.coords['latitude'].values, agg.coords['longitude'].values
# Corners of the image, which need to be passed to mapbox
coordinates = [[coords_lon[0], coords_lat[0]],
               [coords_lon[-1], coords_lat[0]],
               [coords_lon[-1], coords_lat[-1]],
               [coords_lon[0], coords_lat[-1]]]
